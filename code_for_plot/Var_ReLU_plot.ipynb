# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
# !rm -rf result_plot

# %%
# !python var_relu_plot.py --scenario s1
# Out:
# Namespace(num_samples=6000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=1, data_dir='./data/', output_dir='./result_plot/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']

# %%
# !python var_relu_plot.py --scenario s2
# Out:
# Namespace(num_samples=6000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=1, data_dir='./data/', output_dir='./result_plot/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']

# %%
# !python var_relu_plot.py --scenario s3
# Out:
# Namespace(num_samples=6000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=1, data_dir='./data/', output_dir='./result_plot/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
