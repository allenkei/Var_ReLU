# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
# !python var_relu_split.py --scenario s1 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0129)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0125)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0131)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0132)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0125)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0125)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0126)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0124)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0125)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0123)
#
#
# mean of MSE_g_M1_holder: tensor(0.0123)
# ...

# %%
# !python var_relu_split.py --scenario s2 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0198)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0191)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0180)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0183)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0174)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0179)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0179)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0174)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0172)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0179)
#
#
# mean of MSE_g_M1_holder: tensor(0.0179)
# ...

# %%
# !python var_relu_split.py --scenario s3 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0127)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0118)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0128)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0133)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0129)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0129)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0134)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0137)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0132)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0129)
#
#
# mean of MSE_g_M1_holder: tensor(0.0129)
# ...

# %%
# !python var_relu_split.py --scenario s4 --input_dim 5 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.8522)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.9141)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.9138)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(1.0121)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(1.0125)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(1.0335)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(1.1008)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(1.1036)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(1.0851)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(1.0655)
#
#
# mean of MSE_g_M1_holder: tensor(1.0655)
# ...

# %%
# !python var_relu_split.py --scenario s5 --input_dim 5 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.7183)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.6236)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.5720)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.5915)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.5553)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.5558)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.5425)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.5372)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.5351)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.5320)
#
#
# mean of MSE_g_M1_holder: tensor(0.5320)
# ...

# %%
# !python var_relu_split.py --scenario s1 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0051)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0047)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0050)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0051)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0049)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0054)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0052)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0051)
#
#
# mean of MSE_g_M1_holder: tensor(0.0051)
# ...

# %%
# !python var_relu_split.py --scenario s2 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0085)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0081)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0081)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0080)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0078)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0084)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0084)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0082)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0081)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0080)
#
#
# mean of MSE_g_M1_holder: tensor(0.0080)
# ...

# %%
# !python var_relu_split.py --scenario s3 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0049)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0051)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0052)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0054)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0055)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0058)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0058)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0059)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0057)
#
#
# mean of MSE_g_M1_holder: tensor(0.0057)
# ...

# %%
# !python var_relu_split.py --scenario s4 --input_dim 5 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.6766)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.5877)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.5180)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.5192)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.5267)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.5472)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.5983)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.5880)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.5802)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.5866)
#
#
# mean of MSE_g_M1_holder: tensor(0.5866)
# ...

# %%
# !python var_relu_split.py --scenario s5 --input_dim 5 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.2866)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.2653)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.2852)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.2690)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.2559)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.2705)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.2841)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.2816)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.2750)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.2839)
#
#
# mean of MSE_g_M1_holder: tensor(0.2839)
# ...

# %%
# !python var_relu_split.py --scenario s1 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0037)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0037)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0037)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0036)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0037)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0037)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0036)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0036)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0035)
#
#
# mean of MSE_g_M1_holder: tensor(0.0035)
# ...

# %%
# !python var_relu_split.py --scenario s2 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0056)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0052)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0055)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0057)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0057)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0056)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0056)
#
#
# mean of MSE_g_M1_holder: tensor(0.0056)
# ...

# %%
# !python var_relu_split.py --scenario s3 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0033)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0034)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0034)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0035)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0034)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0034)
#
#
# mean of MSE_g_M1_holder: tensor(0.0034)
# ...

# %%
# !python var_relu_split.py --scenario s4 --input_dim 5 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.4718)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.4349)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.3810)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.3731)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.3515)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.3798)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.4385)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.4295)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.4156)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.4173)
#
#
# mean of MSE_g_M1_holder: tensor(0.4173)
# ...

# %%
# !python var_relu_split.py --scenario s5 --input_dim 5 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result_split/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.1702)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.2022)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.1948)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.1793)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.1755)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.1819)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.1895)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.1986)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.1945)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.1917)
#
#
# mean of MSE_g_M1_holder: tensor(0.1917)
# ...
