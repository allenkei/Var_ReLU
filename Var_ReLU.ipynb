# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
#!rm -rf data
#!rm -rf result

# %%
# !python sim_s1.py --num_trials 100 --num_samples 2000
# !python sim_s1.py --num_trials 100 --num_samples 4000
# !python sim_s1.py --num_trials 100 --num_samples 6000
# !python sim_s2.py --num_trials 100 --num_samples 2000
# !python sim_s2.py --num_trials 100 --num_samples 4000
# !python sim_s2.py --num_trials 100 --num_samples 6000
# !python sim_s3.py --num_trials 100 --num_samples 2000
# !python sim_s3.py --num_trials 100 --num_samples 4000
# !python sim_s3.py --num_trials 100 --num_samples 6000
# !python sim_s4.py --num_trials 100 --num_samples 2000
# !python sim_s4.py --num_trials 100 --num_samples 4000
# !python sim_s4.py --num_trials 100 --num_samples 6000
# !python sim_s5.py --num_trials 100 --num_samples 2000
# !python sim_s5.py --num_trials 100 --num_samples 4000
# !python sim_s5.py --num_trials 100 --num_samples 6000

# %%
# !python var_relu.py --scenario s1 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0052)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0049)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0048)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0045)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0044)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0046)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0046)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0046)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0045)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0045)
#
#
# mean of MSE_g_M1_holder: tensor(0.0045)
# ...

# %%
# !python var_relu.py --scenario s2 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0106)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0083)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0079)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0078)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0076)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0078)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0079)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0076)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0075)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0074)
#
#
# mean of MSE_g_M1_holder: tensor(0.0074)
# ...

# %%
# !python var_relu.py --scenario s3 --input_dim 2 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0056)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0055)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0055)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0054)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0054)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0054)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0053)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0053)
#
#
# mean of MSE_g_M1_holder: tensor(0.0053)
# ...

# %%
# !python var_relu.py --scenario s4 --input_dim 5 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.5480)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.4880)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.4290)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.4268)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.4156)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.4191)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.5115)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.5038)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.4936)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.4855)
#
#
# mean of MSE_g_M1_holder: tensor(0.4855)
# ...

# %%
# !python var_relu.py --scenario s5 --input_dim 5 --num_samples 2000 --hidden_dim 64
# Out:
# Namespace(num_samples=2000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.2214)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.2123)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.2079)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.2138)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.2045)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.2168)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.2204)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.2171)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.2138)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.2092)
#
#
# mean of MSE_g_M1_holder: tensor(0.2092)
# ...

# %%
# !python var_relu.py --scenario s1 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0022)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0019)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0020)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0021)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0020)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0021)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0021)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0020)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0020)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0020)
#
#
# mean of MSE_g_M1_holder: tensor(0.0020)
# ...

# %%
# !python var_relu.py --scenario s2 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0043)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0039)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0039)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0041)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0040)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0040)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0039)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0039)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0038)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0038)
#
#
# mean of MSE_g_M1_holder: tensor(0.0038)
# ...

# %%
# !python var_relu.py --scenario s3 --input_dim 2 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0024)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0019)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0020)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0021)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0021)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0022)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0022)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0023)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0022)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0022)
#
#
# mean of MSE_g_M1_holder: tensor(0.0022)
# ...

# %%
# !python var_relu.py --scenario s4 --input_dim 5 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.2775)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.2638)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.2225)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.2211)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.2246)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.2306)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.2952)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.2892)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.2891)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.2967)
#
#
# mean of MSE_g_M1_holder: tensor(0.2967)
# ...

# %%
# !python var_relu.py --scenario s5 --input_dim 5 --num_samples 4000 --hidden_dim 64
# Out:
# Namespace(num_samples=4000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.1343)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.1304)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.1251)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.1212)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.1202)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.1278)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.1383)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.1343)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.1303)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.1357)
#
#
# mean of MSE_g_M1_holder: tensor(0.1357)
# ...

# %%
# !python var_relu.py --scenario s1 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s1', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0018)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0016)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0016)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0016)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0016)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0015)
#
#
# mean of MSE_g_M1_holder: tensor(0.0015)
# ...

# %%
# !python var_relu.py --scenario s2 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s2', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0028)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0026)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0027)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0027)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0027)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0027)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0027)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0028)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0028)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0028)
#
#
# mean of MSE_g_M1_holder: tensor(0.0028)
# ...

# %%
# !python var_relu.py --scenario s3 --input_dim 2 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s3', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0015)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0014)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0014)
#
#
# mean of MSE_g_M1_holder: tensor(0.0014)
# ...

# %%
# !python var_relu.py --scenario s4 --input_dim 5 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s4', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.1931)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.2007)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.1757)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.1865)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.1851)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.2014)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.2509)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.2418)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.2390)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.2306)
#
#
# mean of MSE_g_M1_holder: tensor(0.2306)
# ...

# %%
# !python var_relu.py --scenario s5 --input_dim 5 --num_samples 6000 --hidden_dim 64
# Out:
# Namespace(num_samples=6000, scenario='s5', input_dim=5, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data/', output_dir='./result/', f=None)
# [INFO] cuda:0
# [INFO] columns: ['x1', 'x2', 'x3', 'x4', 'x5']
# [INFO] Trial 10 of 100 complete, mean of M1 MSE: tensor(0.0825)
# [INFO] Trial 20 of 100 complete, mean of M1 MSE: tensor(0.1008)
# [INFO] Trial 30 of 100 complete, mean of M1 MSE: tensor(0.0943)
# [INFO] Trial 40 of 100 complete, mean of M1 MSE: tensor(0.0873)
# [INFO] Trial 50 of 100 complete, mean of M1 MSE: tensor(0.0882)
# [INFO] Trial 60 of 100 complete, mean of M1 MSE: tensor(0.0910)
# [INFO] Trial 70 of 100 complete, mean of M1 MSE: tensor(0.0966)
# [INFO] Trial 80 of 100 complete, mean of M1 MSE: tensor(0.0965)
# [INFO] Trial 90 of 100 complete, mean of M1 MSE: tensor(0.0938)
# [INFO] Trial 100 of 100 complete, mean of M1 MSE: tensor(0.0925)
#
#
# mean of MSE_g_M1_holder: tensor(0.0925)
# ...
