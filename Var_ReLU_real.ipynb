# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
# !python var_relu_real.py --n 5000
# Out:
# Namespace(n=5000, data='housing', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.0005, lr2=0.0005, lr3=0.0005, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/')
# [INFO] cuda:0
# [INFO] housing data size: (18662, 3)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9562) mean of M1 90% Prop: tensor(0.9118)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9570) mean of M1 90% Prop: tensor(0.9127)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9573) mean of M1 90% Prop: tensor(0.9128)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9570) mean of M1 90% Prop: tensor(0.9125)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9566) mean of M1 90% Prop: tensor(0.9117)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9563) mean of M1 90% Prop: tensor(0.9113)
# [INFO] Trial 70 of 100 complete, mean of M1 95% Prop: tensor(0.9561) mean of M1 90% Prop: tensor(0.9109)
# [INFO] Trial 80 of 100 complete, mean of M1 95% Prop: tensor(0.9561) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 90 of 100 complete, mean of M1 95% Prop: tensor(0.9562) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 100 of 100 complete, mean of M1 95% Prop: tensor(0.9562) mean of M1 90% Prop: tensor(0.9109)
# mean of Prop_g_M1_95_holder: tensor(0.9562)
# mean of Prop_g_M1_90_holder: tensor(0.9109)
# mean of Prop_g_M2_95_holder: tensor(0.9292)
# mean of Prop_g_M2_90_holder: tensor(0.9290)
# mean of Prop_g_M3_95_holder: 0.8545088566827698
# mean of Prop_g_M3_90_holder: 0.7823232323232324
# mean of Prop_g_M4_95_holder: 0.6025611184306836
# mean of Prop_g_M4_90_holder: 0.5844781144781145
# std of Prop_g_M1_95_holder: tensor(0.0030)
# std of Prop_g_M1_90_holder: tensor(0.0046)
# std of Prop_g_M2_95_holder: tensor(0.0688)
# std of Prop_g_M2_90_holder: tensor(0.0689)
# std of Prop_g_M3_95_holder: 0.00573925904303314
# std of Prop_g_M3_90_holder: 0.0068730708171326985
# std of Prop_g_M4_95_holder: 0.00955407344864513
# std of Prop_g_M4_90_holder: 0.008844739700510734

# %%
# !python var_relu_real.py --n 10000
# Out:
# Namespace(n=10000, data='housing', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.0005, lr2=0.0005, lr3=0.0005, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/')
# [INFO] cuda:0
# [INFO] housing data size: (18662, 3)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9567) mean of M1 90% Prop: tensor(0.9114)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9570) mean of M1 90% Prop: tensor(0.9124)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9577) mean of M1 90% Prop: tensor(0.9129)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9578) mean of M1 90% Prop: tensor(0.9130)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9578) mean of M1 90% Prop: tensor(0.9129)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9576) mean of M1 90% Prop: tensor(0.9125)
# [INFO] Trial 70 of 100 complete, mean of M1 95% Prop: tensor(0.9576) mean of M1 90% Prop: tensor(0.9125)
# [INFO] Trial 80 of 100 complete, mean of M1 95% Prop: tensor(0.9578) mean of M1 90% Prop: tensor(0.9126)
# [INFO] Trial 90 of 100 complete, mean of M1 95% Prop: tensor(0.9577) mean of M1 90% Prop: tensor(0.9127)
# [INFO] Trial 100 of 100 complete, mean of M1 95% Prop: tensor(0.9578) mean of M1 90% Prop: tensor(0.9127)
# mean of Prop_g_M1_95_holder: tensor(0.9578)
# mean of Prop_g_M1_90_holder: tensor(0.9127)
# mean of Prop_g_M2_95_holder: tensor(0.9271)
# mean of Prop_g_M2_90_holder: tensor(0.9270)
# mean of Prop_g_M3_95_holder: 0.8957007619487417
# mean of Prop_g_M3_90_holder: 0.8312041099053338
# mean of Prop_g_M4_95_holder: 0.625559916878319
# mean of Prop_g_M4_90_holder: 0.6052770722696836
# std of Prop_g_M1_95_holder: tensor(0.0028)
# std of Prop_g_M1_90_holder: tensor(0.0039)
# std of Prop_g_M2_95_holder: tensor(0.0711)
# std of Prop_g_M2_90_holder: tensor(0.0712)
# std of Prop_g_M3_95_holder: 0.004430459331242863
# std of Prop_g_M3_90_holder: 0.005496500926608287
# std of Prop_g_M4_95_holder: 0.011178420161575527
# std of Prop_g_M4_90_holder: 0.01036793187421084
