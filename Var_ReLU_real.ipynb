# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
# !python var_relu_real.py --n 5000
# Out:
# Namespace(n=5000, data='housing', input_dim=3, hidden_dim=128, output_dim=1, lr1=0.005, lr2=0.005, lr3=0.005, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/')
# [INFO] cuda:0
# [INFO] housing data size: (20640, 4)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9478) mean of M1 90% Prop: tensor(0.8987)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9483) mean of M1 90% Prop: tensor(0.8992)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9484) mean of M1 90% Prop: tensor(0.8990)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9489) mean of M1 90% Prop: tensor(0.8993)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9490) mean of M1 90% Prop: tensor(0.8993)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9491) mean of M1 90% Prop: tensor(0.8995)
# ...

# %%
# !python var_relu_real.py --n 10000
# Out:
# Namespace(n=10000, data='housing', input_dim=3, hidden_dim=128, output_dim=1, lr1=0.005, lr2=0.005, lr3=0.005, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/')
# [INFO] cuda:0
# [INFO] housing data size: (20640, 4)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9495) mean of M1 90% Prop: tensor(0.8994)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9494) mean of M1 90% Prop: tensor(0.8997)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9499) mean of M1 90% Prop: tensor(0.9000)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9498) mean of M1 90% Prop: tensor(0.9001)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9495) mean of M1 90% Prop: tensor(0.8997)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9495) mean of M1 90% Prop: tensor(0.8997)
# ...
