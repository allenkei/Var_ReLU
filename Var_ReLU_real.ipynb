# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Var_ReLU
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Var_ReLU

# %%
# !python var_relu_real.py --n 5000
# Out:
# Namespace(n=5000, data='housing', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/', f=None)
# [INFO] cuda:0
# [INFO] housing data size: (18662, 3)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9540) mean of M1 90% Prop: tensor(0.9096)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9528) mean of M1 90% Prop: tensor(0.9086)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9535) mean of M1 90% Prop: tensor(0.9093)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9526) mean of M1 90% Prop: tensor(0.9083)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9526) mean of M1 90% Prop: tensor(0.9084)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9526) mean of M1 90% Prop: tensor(0.9084)
# [INFO] Trial 70 of 100 complete, mean of M1 95% Prop: tensor(0.9520) mean of M1 90% Prop: tensor(0.9077)
# [INFO] Trial 80 of 100 complete, mean of M1 95% Prop: tensor(0.9525) mean of M1 90% Prop: tensor(0.9082)
# [INFO] Trial 90 of 100 complete, mean of M1 95% Prop: tensor(0.9528) mean of M1 90% Prop: tensor(0.9087)
# [INFO] Trial 100 of 100 complete, mean of M1 95% Prop: tensor(0.9528) mean of M1 90% Prop: tensor(0.9086)
# mean of Prop_g_M1_95_holder: tensor(0.9528)
# mean of Prop_g_M1_90_holder: tensor(0.9086)
# mean of Prop_g_M2_95_holder: tensor(0.4431)
# mean of Prop_g_M2_90_holder: tensor(0.4427)
# mean of Prop_g_M3_95_holder: 0.8552591128678085
# mean of Prop_g_M3_90_holder: 0.7835975699019176
# mean of Prop_g_M4_95_holder: 0.6023993558776168
# mean of Prop_g_M4_90_holder: 0.5843405065144196
# std of Prop_g_M1_95_holder: tensor(0.0052)
# std of Prop_g_M1_90_holder: tensor(0.0070)
# std of Prop_g_M2_95_holder: tensor(0.0089)
# std of Prop_g_M2_90_holder: tensor(0.0089)
# std of Prop_g_M3_95_holder: 0.006591016989604944
# std of Prop_g_M3_90_holder: 0.00730472432635796
# std of Prop_g_M4_95_holder: 0.010041498409788394
# std of Prop_g_M4_90_holder: 0.00946369281169176

# %%
# !python var_relu_real.py --n 10000
# Out:
# Namespace(n=10000, data='housing', input_dim=2, hidden_dim=64, output_dim=1, lr1=0.001, lr2=0.001, lr3=0.001, num_epochs=1000, num_trials=100, data_dir='./data_real/', output_dir='./result_real/', f=None)
# [INFO] cuda:0
# [INFO] housing data size: (18662, 3)
# [INFO] Trial 10 of 100 complete, mean of M1 95% Prop: tensor(0.9539) mean of M1 90% Prop: tensor(0.9106)
# [INFO] Trial 20 of 100 complete, mean of M1 95% Prop: tensor(0.9547) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 30 of 100 complete, mean of M1 95% Prop: tensor(0.9550) mean of M1 90% Prop: tensor(0.9115)
# [INFO] Trial 40 of 100 complete, mean of M1 95% Prop: tensor(0.9549) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 50 of 100 complete, mean of M1 95% Prop: tensor(0.9548) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 60 of 100 complete, mean of M1 95% Prop: tensor(0.9548) mean of M1 90% Prop: tensor(0.9109)
# [INFO] Trial 70 of 100 complete, mean of M1 95% Prop: tensor(0.9548) mean of M1 90% Prop: tensor(0.9110)
# [INFO] Trial 80 of 100 complete, mean of M1 95% Prop: tensor(0.9549) mean of M1 90% Prop: tensor(0.9111)
# [INFO] Trial 90 of 100 complete, mean of M1 95% Prop: tensor(0.9547) mean of M1 90% Prop: tensor(0.9109)
# [INFO] Trial 100 of 100 complete, mean of M1 95% Prop: tensor(0.9547) mean of M1 90% Prop: tensor(0.9108)
# mean of Prop_g_M1_95_holder: tensor(0.9547)
# mean of Prop_g_M1_90_holder: tensor(0.9108)
# mean of Prop_g_M2_95_holder: tensor(0.4446)
# mean of Prop_g_M2_90_holder: tensor(0.4442)
# mean of Prop_g_M3_95_holder: 0.8951039021011314
# mean of Prop_g_M3_90_holder: 0.8304744862618333
# mean of Prop_g_M4_95_holder: 0.6250808127453243
# mean of Prop_g_M4_90_holder: 0.6049642114984991
# std of Prop_g_M1_95_holder: tensor(0.0038)
# std of Prop_g_M1_90_holder: tensor(0.0051)
# std of Prop_g_M2_95_holder: tensor(0.0104)
# std of Prop_g_M2_90_holder: tensor(0.0104)
# std of Prop_g_M3_95_holder: 0.0037281586761470495
# std of Prop_g_M3_90_holder: 0.004536463664609196
# std of Prop_g_M4_95_holder: 0.009653924115510032
# std of Prop_g_M4_90_holder: 0.008783868914668936
